# %%
# Import library #
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Step 1 reading and dataset

# %%
# import football dataset #
fd = pd.read_csv("foodball.csv")
fd.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
# Remove all missing rows
fd = fd.fillna(0)

# %% [markdown]
# Step 2 Exploring the datasets

# %%
#How many tuples are there in the dataset?
len(fd)
# Out:
# 42650

# %%
#How many tournaments are there in the dataset?
len(fd.tournament.unique())
# Out:
# 120

# %% [markdown]
# Sep 4- Convert and Deduce

# %% [markdown]
# #Convert the column date to timestamps!
# fd1 = fd["date]

# %%
fd1 = fd["date"]

# %%
# Convert the date column to datetime type
fd['date']= pd.to_datetime(fd['date'])
# Extract the year from the date column
fd["year"] = fd['date'].dt.year
fd[fd.year==2018]
# Out:
#             date             home_team             away_team  home_score  \
# 39574 2018-01-02                  Iraq  United Arab Emirates           0
# 39575 2018-01-02                  Oman               Bahrain           1
# 39576 2018-01-05                  Oman  United Arab Emirates           0
# 39577 2018-01-07               Estonia                Sweden           1
# 39578 2018-01-11               Denmark                Sweden           0
# 39579 2018-01-11             Indonesia               Iceland           0
# 39580 2018-01-11                Jordan               Finland           1
# 39581 2018-01-13               Morocco            Mauritania           4
# 39582 2018-01-14             Indonesia               Iceland           1
# 39583 2018-01-14                Guinea                 Sudan           1
# 39584 2018-01-14           Ivory Coast               Namibia           0
# 39585 2018-01-14                Zambia                Uganda           3
# ...

# %% [markdown]
# Step 5 Team Statistics

# %% [markdown]
# #Calculate how many times the home team won, lost, or had a draw.

# %%
fd.head(4)
# Out:
#         date home_team away_team  home_score  away_score tournament     city  \
# 0 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1 1873-03-08   England  Scotland           4           2   Friendly   London
# 2 1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3 1875-03-06   England  Scotland           2           2   Friendly   London
#
#     country  neutral  year
# 0  Scotland    False  1872
# 1   England    False  1873
# 2  Scotland    False  1874
# 3   England    False  1875

# %%
Home_T =fd[(fd['home_team']==fd['country'])]
Home_T.shape
# Out:
# (31332, 10)

# %% [markdown]
# Step 5 Visualization

# %%
#Plot the neutral column as a pie chart.
#plt.pie(Home_T['home_team'])
#plt.pie(Home_T['home_team'])
#species_freq = data['species'].value_counts()
fd_freq =Home_T['neutral'].value_counts()
fd_freq
# Out:
# False    31322
# True        10
# Name: neutral, dtype: int64

# %%
plt.pie(fd_freq)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bf288baef0>,
# ...
#  [Text(-1.1,0.00110302,''), Text(1.1,-0.00110309,'')])

# %% [markdown]
# Step 7 Unique Teams

# %%
#How many unique teams are there in the dataset?
# unique from home team
len(fd.home_team.unique())
#df[df.ReviewDate == 2013]
# Out:
# 308

# %%
uniq_Hteam =fd['home_team']
uniq_Ateam =fd['away_team']

# %%
new = uniq_Hteam.append(uniq_Ateam, ignore_index=True)

# %%
#df1.append(df2, ignore_index=True)
len(new.unique())
# Out:
# 313
